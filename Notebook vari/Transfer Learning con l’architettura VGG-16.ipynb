# %%
#Transfer Learning con l’architettura VGG-16

import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

import pandas as pd
import os
import matplotlib.pyplot as plt
from textwrap import wrap
from keras_preprocessing.image import ImageDataGenerator, load_img, img_to_array

df_captions = pd.read_csv("flickr8k_captions.csv")

def readImage(path, img_size=224):
     img = load_img(path, color_mode='rgb', target_size=(img_size, img_size))
     img = img_to_array(img)
     img = img/255.

     return img

 def display_images(df_captions):

     plt.figure(figsize = (20 , 20))


from keras.applications import VGG16
vgg16 = VGG16()

vgg16.summary()




from keras.models import Model
vgg16 = Model(inputs=vgg16.inputs, outputs=vgg16.layers[-2].output)



from keras.applications.vgg16 import preprocess_input
image_features = dict()
for name in os.listdir("./flickr_images"):
    filename = "./flickr_images/" + name
    image = load_img(filename, target_size=(224,224))
    image = img_to_array(image)
    image = image.reshape(1, image.shape[0], image.shape[1], image.shape[2])
    image = preprocess_input(image)
    feature = vgg16.predict(image, verbose=0)
    image_features[name] = feature.flatten()

with open("image_features.pkl", "wb") as f:
     pickle.dump(image_features, f)

import pickle
with open("image_features.pkl", "rb") as f:
     image_features = pickle.load(f)

image_features["667626_18933d713e.jpg"].shape
