# %%
#Notebook Deep Learning reti neurali.

import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

import pandas as pd
import matplotlib.pyplot as plt
from keras_preprocessing.image import load_img, img_to_array
from textwrap import wrap

df_captions = pd.read_csv("flickr8k_captions.csv")
df_captions.head(20)

def readImage(path,img_size=224):
       img = load_img(path,color_mode='rgb',target_size=(img_size,img_size))
       img = img_to_array(img)
       img = img/255.

       return img

def display_images(df_captions):

       plt.figure(figsize = (20 , 20))
       for i in range(25):

          plt.subplot(5 ,5 , i+1)
          plt.subplots_adjust(hspace = 0.5)




 def readImage(path, img_size=224):
       img = load_img(path,color_mode='rgb' ,target_size=(img_size, img_size))
       img = img_to_array(img)
       img = img/255.

       return img

def display_images(df_captions):

       plt.figure(figsize = (20 , 20))
       for i in range(25):
            plt.subplot(5 ,5, i+1)
            plt.subplots_adjust(hspace = 0.5)
            image = readImage(f"./flickr_images/{df_captions.image[i]}")
            plt.imshow(image)
        plt.title(("\n".join(wrap(df_captions.caption[i], 20))), loc="right")
        plt.axis("off")

display_images(df_captions)
